# %%
#Q1  Add Two Numbers Input two numbers and print their sum.
a = int(input())
b = int(input())

print(a + b)
# Out:
# 3
# 5
# 8

# %%
#Q2 Subtract Two Numbers Input two numbers and print their difference.
a = int(input())
b = int(input())

print(a - b)
# Out:
# 67
# 44
# 23

# %%
#Q3 Multiply Two Numbers Input two numbers and print their difference.
a = int(input())
b = int(input())

print(a * b)
# Out:
# 5
# 5
# 25

# %%
#Q4 Divide Two Numbers Input two numbers and print their difference.
a = int(input())
b = int(input())

print(a / b)
# Out:
# 8
# 4
# 2.0

# %%
#Q5 Find the Remainder Input two numbers and print their difference.
a = int(input())
b = int(input())

print(a % b)
# Out:
# 5
# 6
# 5

# %%
#Q6 Find the Square Input two numbers and print their difference.
n = int(input())

print(n ** 2)
# Out:
# 6
# 36

# %%
#Q7 Find the Cube Input a number and print its cube.
n = int(input())

print(n ** 3)
# Out:
# 6
# 216

# %%
#Q8. Swap Two Numbers Swap two numbers without using a third variable.
a = int(input())
b = int(input())

a, b = b, a

print(a)
print(b)
# Out:
# 23
# 87
# 87
# 23

# %%
#Q9. Find the Average of Three Numbers Input three numbers and print their average.
a = int(input())
b = int(input())
c = int(input())

avg = (a + b + c) / 3

print(avg)
# Out:
# 56
# 76
# 45
# 59.0

# %%
#Q10. Celsius to Fahrenheit Convert Celsius into Fahrenheit.
c = float(input())

f = (c * 9/5) + 32

print(f)
# Out:
# 67
# 152.6
