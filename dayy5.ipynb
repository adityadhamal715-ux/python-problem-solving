# %%
# Q41. Find the Least Common Multiple (LCM)

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

greater = max(a, b)

while True:
    if greater % a == 0 and greater % b == 0:
        print("LCM =", greater)
        break
    greater += 1
# Out:
# Enter first number:  67
# Enter second number:  87
# LCM = 5829

# %%
# Q42. Check Whether a Number is a Strong Number

num = int(input("Enter a number: "))

temp = num
total = 0

while temp > 0:
    digit = temp % 10
    fact = 1

    for i in range(1, digit + 1):
        fact *= i

    total += fact
    temp //= 10

if total == num:
    print("Strong Number")
else:
    print("Not a Strong Number")
# Out:
# Enter a number:  45
# Not a Strong Number

# %%
# Q43. Check Whether a Number is a Perfect Square

num = int(input("Enter a number: "))

root = int(num ** 0.5)

if root * root == num:
    print("Perfect Square")
else:
    print("Not a Perfect Square")
# Out:
# Enter a number:  14
# Not a Perfect Square

# %%
# Q44. Find the Largest Digit in a Number

num = int(input("Enter a number: "))

largest = 0

while num > 0:
    digit = num % 10
    if digit > largest:
        largest = digit
    num //= 10

print("Largest Digit =", largest)
# Out:
# Enter a number:  57
# Largest Digit = 7

# %%
# Q45. Find the Smallest Digit in a Number

num = int(input("Enter a number: "))

smallest = 9

while num > 0:
    digit = num % 10
    if digit < smallest:
        smallest = digit
    num //= 10

print("Smallest Digit =", smallest)
# Out:
# Enter a number:  67
# Smallest Digit = 6

# %%
# Q46. Count Even and Odd Digits
num = int(input("Enter a number: "))

even = 0
odd = 0

while num > 0:
    digit = num % 10

    if digit % 2 == 0:
        even += 1
    else:
        odd += 1

    num //= 10

print("Even Digits =", even)
print("Odd Digits =", odd)
# Out:
# Enter a number:  14
# Even Digits = 1
# Odd Digits = 1

# %%
# Q47. Find the Sum of Squares of Digits

num = int(input("Enter a number: "))

total = 0

while num > 0:
    digit = num % 10
    total += digit ** 2
    num //= 10

print("Sum of Squares =", total)
# Out:
# Enter a number:  12
# Sum of Squares = 5

# %%
# Q48. Print ASCII Value of a Character

ch = input("Enter a character: ")

print("ASCII Value =", ord(ch))
# Out:
# Enter a character:  A
# ASCII Value = 65

# %%
# Q49. Convert ASCII Value to Character

ascii_value = int(input("Enter ASCII value: "))

print("Character =", chr(ascii_value))
# Out:
# Enter ASCII value:  65
# Character = A

# %%
# Q50. Check Whether a Character is Alphabet, Digit or Special Character

ch = input("Enter a character: ")

if ch.isalpha():
    print("Alphabet")
elif ch.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter a character:  A
# Alphabet
