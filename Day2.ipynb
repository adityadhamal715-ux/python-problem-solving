# %%
# Q11. Check Even or Odd
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 2
# Even

# %%
# Q12. Check Positive, Negative or Zero

num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: -4
# Negative

# %%
# Q13. Find the Largest of Two Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print(a)
else:
    print(b)
# Out:
# Enter first number: 45
# Enter second number: 67
# 67

# %%
# Q14. Find the Largest of Three Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

largest = max(a, b, c)
print(largest)
# Out:
# Enter first number: 56
# Enter second number: 100
# Enter third number: 101
# 101

# %%
# Q15. Check Leap Year

year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2026
# Not a Leap Year

# %%
# Q16. Calculate Area of a Rectangle

length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area =", area)
# Out:
# Enter length: 20
# Enter width: 10
# Area = 200.0

# %%
# Q17. Calculate Area of a Circle

radius = float(input("Enter radius: "))

area = 3.14159 * radius * radius

print("Area =", area)
# Out:
# Enter radius: 69
# Area = 14957.10999

# %%
# Q18. Calculate Simple Interest

principal = float(input("Enter Principal: "))
rate = float(input("Enter Rate: "))
time = float(input("Enter Time: "))

si = (principal * rate * time) / 100

print("Simple Interest =", si)
# Out:
# Enter Principal: 67
# Enter Rate: 87
# Enter Time: 7
# Simple Interest = 408.03

# %%
# Q19. Calculate Percentage of Five Subjects

s1 = float(input("Enter Subject 1 Marks: "))
s2 = float(input("Enter Subject 2 Marks: "))
s3 = float(input("Enter Subject 3 Marks: "))
s4 = float(input("Enter Subject 4 Marks: "))
s5 = float(input("Enter Subject 5 Marks: "))

percentage = (s1 + s2 + s3 + s4 + s5) / 5

print("Percentage =", percentage)
# Out:
# Enter Subject 1 Marks: 78
# Enter Subject 2 Marks: 87
# Enter Subject 3 Marks: 99
# Enter Subject 4 Marks: 89
# Enter Subject 5 Marks: 98
# Percentage = 90.2

# %%
# Q20. Check Whether a Number is Divisible by 5 and 11

num = int(input("Enter a number: "))

if num % 5 == 0 and num % 11 == 0:
    print("Divisible by both 5 and 11")
else:
    print("Not Divisible by both 5 and 11")
# Out:
# Enter a number: 4
# Not Divisible by both 5 and 11
